# %% [markdown]
# # 평균이동법, 지수평활법, 분해시계열 (모듈)
#
# ## #01. 작업준비
#
# ### 1) 패키지 가져오기

# %%
import warnings
warnings.filterwarnings(action='ignore')

from hossam.util import *
from hossam.plot import *
from hossam.timeserise import *

# %% [markdown]
# ### 2) 데이터 가져오기
#
# 월간 항공 승객 수

# %%
origin = my_read_excel("https://data.hossam.kr/tsdata/air_passengers.xlsx", index_col="Month", info=False)

# %% [markdown]
# ## #02. 데이터 전처리 - 차분
#
# 정상성을 확보할 때 까지 차분을 수행한다.

# %%
diff_df = my_diff(origin, 'Passengers')
my_pretty_table(diff_df.head())
# Out:
# =========== 원본 데이터 ===========
# +----------------------------------+---------------------+
# |                                  | ADF Test            |
# |----------------------------------+---------------------|
# | 검정통계량(ADF Statistic)        | 0.8153688792060482  |
# | 유의수준(p-value)                | 0.991880243437641   |
# | 최적차수(num of lags)            | 13                  |
# | 관측치 개수(num of observations) | 130                 |
# | 기각값(Critical Values) 1%       | -3.4816817173418295 |
# | 기각값(Critical Values) 5%       | -2.8840418343195267 |
# | 기각값(Critical Values) 10%      | -2.578770059171598  |
# | 데이터 정상성 여부               | 비정상              |
# +----------------------------------+---------------------+
# =========== 1차 차분 데이터 ===========
# +----------------------------------+---------------------+
# |                                  | ADF Test            |
# |----------------------------------+---------------------|
# | 검정통계량(ADF Statistic)        | -2.8292668241699994 |
# | 유의수준(p-value)                | 0.0542132902838255  |
# | 최적차수(num of lags)            | 12                  |
# | 관측치 개수(num of observations) | 130                 |
# | 기각값(Critical Values) 1%       | -3.4816817173418295 |
# | 기각값(Critical Values) 5%       | -2.8840418343195267 |
# | 기각값(Critical Values) 10%      | -2.578770059171598  |
# | 데이터 정상성 여부               | 비정상              |
# +----------------------------------+---------------------+
# =========== 2차 차분 데이터 ===========
# +----------------------------------+------------------------+
# |                                  | ADF Test               |
# |----------------------------------+------------------------|
# | 검정통계량(ADF Statistic)        | -16.384231542468505    |
# | 유의수준(p-value)                | 2.7328918500142407e-29 |
# | 최적차수(num of lags)            | 11                     |
# | 관측치 개수(num of observations) | 130                    |
# | 기각값(Critical Values) 1%       | -3.4816817173418295    |
# | 기각값(Critical Values) 5%       | -2.8840418343195267    |
# | 기각값(Critical Values) 10%      | -2.578770059171598     |
# | 데이터 정상성 여부               | 정상                   |
# +----------------------------------+------------------------+
# +---------------------+--------------+
# | Month               |   Passengers |
# |---------------------+--------------|
# | 1949-03-01 00:00:00 |            8 |
# | 1949-04-01 00:00:00 |          -17 |
# | 1949-05-01 00:00:00 |           -5 |
# | 1949-06-01 00:00:00 |           22 |
# | 1949-07-01 00:00:00 |           -1 |
# +---------------------+--------------+

# %% [markdown]
# ## #03. 평균이동법
#
# ### [1] 차분되지 않은 원본에 대한 3개월, 6개월, 9개월 평균

# %%
month3 = my_rolling(origin['Passengers'], window=3)
month6 = my_rolling(origin['Passengers'], window=6)
month9 = my_rolling(origin['Passengers'], window=9)

# %% [markdown]
# > 데이터의 평균을 이동하여 점점 더 그래프가 단순해 진다. 이를 통해 월별 승객 수가 꾸준히 증가하는 추세라는 것을 알 수 있다.
# >
# > 원본 데이터로 확인할 경우 전반적인 경향을 알 수 있다.

# %% [markdown]
# ### [2] 차분된 데이터 대한 3개월, 6개월, 9개월 평균

# %%
month3 = my_rolling(diff_df['Passengers'], window=3)
month6 = my_rolling(diff_df['Passengers'], window=6)
month9 = my_rolling(diff_df['Passengers'], window=9)

# %% [markdown]
# > 평균이동을 할 수록 그래프가 단순해 져서 6개월 주기로 증감을 반복하는 트렌드가 있음을 알 수 있다.

# %% [markdown]
# ## #04. 지수평활법
#
# 보다 최근의 값에 가중치를 두면서 이동평균을 계산하는 방법
#
# ### (1) 원본에 대한 지수평활법

# %%
ewm3 = my_ewm(origin['Passengers'], span=3)
ewm6 = my_ewm(origin['Passengers'], span=6)
ewm9 = my_ewm(origin['Passengers'], span=9)

# %% [markdown]
# ### (2) 차분 결과에 대한 지수평활법

# %%
ewm3 = my_ewm(diff_df['Passengers'], span=3)
ewm6 = my_ewm(diff_df['Passengers'], span=6)
ewm9 = my_ewm(diff_df['Passengers'], span=9)

# %% [markdown]
# > 평균이동법과 지수평활법은 시각화 결과물을 분석가의 주관대로 해석하는 방법이므로 추론통계보다는 탐색적 데이터 분석 과정에 더 가깝다.

# %% [markdown]
# ## #05. 분해시계열
#
# ### [1] 분해 시계열 생성

# %%
sd = my_seasonal_decompose(origin['Passengers'], model="multiplicative")
my_pretty_table(sd)
# Out:
# +---------------------+------------+---------+------------+----------+
# | Month               |   original |   trend |   seasonal |    resid |
# |---------------------+------------+---------+------------+----------|
# | 1949-01-01 00:00:00 |        112 |     nan |    0.91023 |      nan |
# | 1949-02-01 00:00:00 |        118 |     nan |   0.883625 |      nan |
# | 1949-03-01 00:00:00 |        132 |     nan |    1.00737 |      nan |
# | 1949-04-01 00:00:00 |        129 |     nan |   0.975906 |      nan |
# | 1949-05-01 00:00:00 |        121 |     nan |   0.981378 |      nan |
# | 1949-06-01 00:00:00 |        135 |     nan |    1.11278 |      nan |
# | 1949-07-01 00:00:00 |        148 | 126.792 |    1.22656 | 0.951664 |
# | 1949-08-01 00:00:00 |        148 |  127.25 |    1.21991 | 0.953401 |
# | 1949-09-01 00:00:00 |        136 | 127.958 |    1.06049 |  1.00222 |
# | 1949-10-01 00:00:00 |        119 | 128.583 |   0.921757 |  1.00403 |
# | 1949-11-01 00:00:00 |        104 |     129 |   0.801178 |  1.00627 |
# | 1949-12-01 00:00:00 |        118 |  129.75 |   0.898824 |  1.01181 |
# | 1950-01-01 00:00:00 |        115 |  131.25 |    0.91023 | 0.962603 |
# | 1950-02-01 00:00:00 |        126 | 133.083 |   0.883625 |  1.07147 |
# | 1950-03-01 00:00:00 |        141 | 134.917 |    1.00737 |  1.03745 |
# | 1950-04-01 00:00:00 |        135 | 136.417 |   0.975906 |  1.01405 |
# | 1950-05-01 00:00:00 |        125 | 137.417 |   0.981378 | 0.926903 |
# | 1950-06-01 00:00:00 |        149 |  138.75 |    1.11278 | 0.965041 |
# | 1950-07-01 00:00:00 |        170 | 140.917 |    1.22656 | 0.983557 |
# | 1950-08-01 00:00:00 |        170 | 143.167 |    1.21991 | 0.973372 |
# | 1950-09-01 00:00:00 |        158 | 145.708 |    1.06049 |   1.0225 |
# | 1950-10-01 00:00:00 |        133 | 148.417 |   0.921757 | 0.972193 |
# | 1950-11-01 00:00:00 |        114 | 151.542 |   0.801178 | 0.938953 |
# | 1950-12-01 00:00:00 |        140 | 154.708 |   0.898824 |  1.00679 |
# | 1951-01-01 00:00:00 |        145 | 157.125 |    0.91023 |  1.01384 |
# | 1951-02-01 00:00:00 |        150 | 159.542 |   0.883625 |  1.06402 |
# | 1951-03-01 00:00:00 |        178 | 161.833 |    1.00737 |  1.09185 |
# | 1951-04-01 00:00:00 |        163 | 164.125 |   0.975906 |  1.01767 |
# | 1951-05-01 00:00:00 |        172 | 166.667 |   0.981378 |  1.05158 |
# | 1951-06-01 00:00:00 |        178 | 169.083 |    1.11278 | 0.946044 |
# | 1951-07-01 00:00:00 |        199 |  171.25 |    1.22656 | 0.947404 |
# | 1951-08-01 00:00:00 |        199 | 173.583 |    1.21991 |  0.93976 |
# | 1951-09-01 00:00:00 |        184 | 175.458 |    1.06049 | 0.988864 |
# | 1951-10-01 00:00:00 |        162 | 176.833 |   0.921757 | 0.993881 |
# | 1951-11-01 00:00:00 |        146 | 178.042 |   0.801178 |  1.02353 |
# | 1951-12-01 00:00:00 |        166 | 180.167 |   0.898824 |  1.02508 |
# | 1952-01-01 00:00:00 |        171 | 183.125 |    0.91023 |  1.02588 |
# | 1952-02-01 00:00:00 |        180 | 186.208 |   0.883625 |  1.09397 |
# | 1952-03-01 00:00:00 |        193 | 189.042 |    1.00737 |  1.01347 |
# | 1952-04-01 00:00:00 |        181 | 191.292 |   0.975906 |  0.96956 |
# | 1952-05-01 00:00:00 |        183 | 193.583 |   0.981378 | 0.963267 |
# | 1952-06-01 00:00:00 |        218 | 195.833 |    1.11278 |  1.00037 |
# | 1952-07-01 00:00:00 |        230 | 198.042 |    1.22656 | 0.946856 |
# | 1952-08-01 00:00:00 |        242 |  199.75 |    1.21991 | 0.993117 |
# | 1952-09-01 00:00:00 |        209 | 202.208 |    1.06049 |  0.97463 |
# | 1952-10-01 00:00:00 |        191 |  206.25 |   0.921757 |  1.00467 |
# | 1952-11-01 00:00:00 |        172 | 210.417 |   0.801178 |  1.02028 |
# | 1952-12-01 00:00:00 |        194 | 213.375 |   0.898824 |  1.01154 |
# | 1953-01-01 00:00:00 |        196 | 215.833 |    0.91023 | 0.997668 |
# | 1953-02-01 00:00:00 |        196 |   218.5 |   0.883625 |  1.01516 |
# | 1953-03-01 00:00:00 |        236 | 220.917 |    1.00737 |  1.06046 |
# | 1953-04-01 00:00:00 |        235 | 222.917 |   0.975906 |  1.08023 |
# | 1953-05-01 00:00:00 |        229 | 224.083 |   0.981378 |  1.04133 |
# | 1953-06-01 00:00:00 |        243 | 224.708 |    1.11278 | 0.971806 |
# | 1953-07-01 00:00:00 |        264 | 225.333 |    1.22656 | 0.955193 |
# | 1953-08-01 00:00:00 |        272 | 225.333 |    1.21991 | 0.989499 |
# | 1953-09-01 00:00:00 |        237 | 224.958 |    1.06049 | 0.993434 |
# | 1953-10-01 00:00:00 |        211 | 224.583 |   0.921757 |  1.01927 |
# | 1953-11-01 00:00:00 |        180 | 224.458 |   0.801178 |  1.00094 |
# | 1953-12-01 00:00:00 |        201 | 225.542 |   0.898824 | 0.991504 |
# | 1954-01-01 00:00:00 |        204 |     228 |    0.91023 | 0.982978 |
# | 1954-02-01 00:00:00 |        188 | 230.458 |   0.883625 | 0.923203 |
# | 1954-03-01 00:00:00 |        235 |  232.25 |    1.00737 |  1.00444 |
# | 1954-04-01 00:00:00 |        227 | 233.917 |   0.975906 |  0.99439 |
# | 1954-05-01 00:00:00 |        234 | 235.625 |   0.981378 |  1.01195 |
# | 1954-06-01 00:00:00 |        264 |  237.75 |    1.11278 | 0.997874 |
# | 1954-07-01 00:00:00 |        302 |   240.5 |    1.22656 |  1.02378 |
# | 1954-08-01 00:00:00 |        293 | 243.958 |    1.21991 | 0.984518 |
# | 1954-09-01 00:00:00 |        259 | 247.167 |    1.06049 | 0.988104 |
# | 1954-10-01 00:00:00 |        229 |  250.25 |   0.921757 | 0.992761 |
# | 1954-11-01 00:00:00 |        203 |   253.5 |   0.801178 | 0.999514 |
# | 1954-12-01 00:00:00 |        229 | 257.125 |   0.898824 | 0.990869 |
# | 1955-01-01 00:00:00 |        242 | 261.833 |    0.91023 |   1.0154 |
# | 1955-02-01 00:00:00 |        233 | 266.667 |   0.883625 | 0.988824 |
# | 1955-03-01 00:00:00 |        267 | 271.125 |    1.00737 | 0.977584 |
# | 1955-04-01 00:00:00 |        269 | 275.208 |   0.975906 |  1.00157 |
# | 1955-05-01 00:00:00 |        270 |   278.5 |   0.981378 | 0.987876 |
# | 1955-06-01 00:00:00 |        315 | 281.958 |    1.11278 |  1.00396 |
# | 1955-07-01 00:00:00 |        364 |  285.75 |    1.22656 |  1.03855 |
# | 1955-08-01 00:00:00 |        347 | 289.333 |    1.21991 | 0.983112 |
# | 1955-09-01 00:00:00 |        312 |  293.25 |    1.06049 |  1.00325 |
# | 1955-10-01 00:00:00 |        274 | 297.167 |   0.921757 |  1.00031 |
# | 1955-11-01 00:00:00 |        237 |     301 |   0.801178 | 0.982772 |
# | 1955-12-01 00:00:00 |        278 | 305.458 |   0.898824 |  1.01255 |
# | 1956-01-01 00:00:00 |        284 | 309.958 |    0.91023 |  1.00662 |
# | 1956-02-01 00:00:00 |        277 | 314.417 |   0.883625 | 0.997025 |
# | 1956-03-01 00:00:00 |        317 | 318.625 |    1.00737 | 0.987625 |
# | 1956-04-01 00:00:00 |        313 |  321.75 |   0.975906 | 0.996822 |
# | 1956-05-01 00:00:00 |        318 |   324.5 |   0.981378 | 0.998564 |
# | 1956-06-01 00:00:00 |        374 | 327.083 |    1.11278 |  1.02756 |
# | 1956-07-01 00:00:00 |        413 | 329.542 |    1.22656 |  1.02177 |
# | 1956-08-01 00:00:00 |        405 | 331.833 |    1.21991 |  1.00048 |
# | 1956-09-01 00:00:00 |        355 | 334.458 |    1.06049 |  1.00087 |
# | 1956-10-01 00:00:00 |        306 | 337.542 |   0.921757 | 0.983507 |
# | 1956-11-01 00:00:00 |        271 | 340.542 |   0.801178 | 0.993276 |
# | 1956-12-01 00:00:00 |        306 | 344.083 |   0.898824 | 0.989425 |
# | 1957-01-01 00:00:00 |        315 |  348.25 |    0.91023 | 0.993729 |
# | 1957-02-01 00:00:00 |        301 |     353 |   0.883625 | 0.964992 |
# | 1957-03-01 00:00:00 |        356 | 357.625 |    1.00737 | 0.988177 |
# | 1957-04-01 00:00:00 |        348 | 361.375 |   0.975906 | 0.986764 |
# | 1957-05-01 00:00:00 |        355 |   364.5 |   0.981378 | 0.992418 |
# | 1957-06-01 00:00:00 |        422 | 367.167 |    1.11278 |  1.03286 |
# | 1957-07-01 00:00:00 |        465 | 369.458 |    1.22656 |  1.02612 |
# | 1957-08-01 00:00:00 |        467 | 371.208 |    1.21991 |  1.03127 |
# | 1957-09-01 00:00:00 |        404 | 372.167 |    1.06049 |  1.02361 |
# | 1957-10-01 00:00:00 |        347 | 372.417 |   0.921757 |  1.01084 |
# | 1957-11-01 00:00:00 |        305 |  372.75 |   0.801178 |   1.0213 |
# | 1957-12-01 00:00:00 |        336 | 373.625 |   0.898824 |  1.00053 |
# | 1958-01-01 00:00:00 |        340 |  375.25 |    0.91023 | 0.995421 |
# | 1958-02-01 00:00:00 |        318 | 377.917 |   0.883625 | 0.952276 |
# | 1958-03-01 00:00:00 |        362 |   379.5 |    1.00737 | 0.946911 |
# | 1958-04-01 00:00:00 |        348 |     380 |   0.975906 | 0.938399 |
# | 1958-05-01 00:00:00 |        363 | 380.708 |   0.981378 | 0.971579 |
# | 1958-06-01 00:00:00 |        435 | 380.958 |    1.11278 |  1.02613 |
# | 1958-07-01 00:00:00 |        491 | 381.833 |    1.22656 |  1.04838 |
# | 1958-08-01 00:00:00 |        505 | 383.667 |    1.21991 |  1.07897 |
# | 1958-09-01 00:00:00 |        404 |   386.5 |    1.06049 | 0.985654 |
# | 1958-10-01 00:00:00 |        359 | 390.333 |   0.921757 | 0.997797 |
# | 1958-11-01 00:00:00 |        310 | 394.708 |   0.801178 | 0.980294 |
# | 1958-12-01 00:00:00 |        337 | 398.625 |   0.898824 | 0.940569 |
# | 1959-01-01 00:00:00 |        360 | 402.542 |    0.91023 | 0.982518 |
# | 1959-02-01 00:00:00 |        342 | 407.167 |   0.883625 | 0.950574 |
# | 1959-03-01 00:00:00 |        406 | 411.875 |    1.00737 | 0.978528 |
# | 1959-04-01 00:00:00 |        396 | 416.333 |   0.975906 | 0.974644 |
# | 1959-05-01 00:00:00 |        420 |   420.5 |   0.981378 |  1.01776 |
# | 1959-06-01 00:00:00 |        472 |   425.5 |    1.11278 | 0.996861 |
# | 1959-07-01 00:00:00 |        548 | 430.708 |    1.22656 |  1.03731 |
# | 1959-08-01 00:00:00 |        559 | 435.125 |    1.21991 |   1.0531 |
# | 1959-09-01 00:00:00 |        463 | 437.708 |    1.06049 | 0.997445 |
# | 1959-10-01 00:00:00 |        407 | 440.958 |   0.921757 |  1.00134 |
# | 1959-11-01 00:00:00 |        362 | 445.833 |   0.801178 |  1.01346 |
# | 1959-12-01 00:00:00 |        405 | 450.625 |   0.898824 | 0.999919 |
# | 1960-01-01 00:00:00 |        417 | 456.333 |    0.91023 |  1.00393 |
# | 1960-02-01 00:00:00 |        391 | 461.375 |   0.883625 | 0.959079 |
# | 1960-03-01 00:00:00 |        419 | 465.208 |    1.00737 | 0.894086 |
# | 1960-04-01 00:00:00 |        461 | 469.333 |   0.975906 |  1.00649 |
# | 1960-05-01 00:00:00 |        472 |  472.75 |   0.981378 |  1.01736 |
# | 1960-06-01 00:00:00 |        535 | 475.042 |    1.11278 |  1.01208 |
# | 1960-07-01 00:00:00 |        622 |     nan |    1.22656 |      nan |
# | 1960-08-01 00:00:00 |        606 |     nan |    1.21991 |      nan |
# | 1960-09-01 00:00:00 |        508 |     nan |    1.06049 |      nan |
# | 1960-10-01 00:00:00 |        461 |     nan |   0.921757 |      nan |
# | 1960-11-01 00:00:00 |        390 |     nan |   0.801178 |      nan |
# | 1960-12-01 00:00:00 |        432 |     nan |   0.898824 |      nan |
# +---------------------+------------+---------+------------+----------+

# %% [markdown]
# > 원본 데이터를 분해 했을 때 전반적으로 증가하는 추세(Trend)를 보이고 있으며, 1년 단위로 데이터 패턴이 반복되고 있다(Seasonal). 전체 평균은 1을 기준으로 크게 벗어나지 않는 잔차를 보이는 것으로 보아 분석 결과가 타당해 보인다.
