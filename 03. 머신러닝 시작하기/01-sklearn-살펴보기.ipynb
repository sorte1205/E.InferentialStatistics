# %% [markdown]
# # Sklean 살펴보기
#
# ## #01. 준비작업
#
# ### [1] 패키지 참조

# %%
from sklearn.utils import all_estimators
from pandas import DataFrame
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from sklearn.utils import all_estimators, memory_profiler
#       2 from pandas import DataFrame
#
# ImportError: cannot import name 'memory_profiler' from 'sklearn.utils' (c:\Users\User\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\__init__.py)

# %% [markdown]
# ## #02. sklearn이 제공하는 알고리즘 확인

# %%
filterType = ['classifier', 'regressor', 'cluster', 'transformer']
mylist = []

for f in filterType:
    allAlgorithms = all_estimators(type_filter=f)

    for name, package in allAlgorithms:
        cls = str(package)
        x = cls.find("'")
        y = cls.rfind("'")
        clsName = cls[x+1:y]

        if clsName.find("._") > -1:
            continue

        mylist.append({"type": f, "name": name, "class": clsName})

df = DataFrame(mylist)
df.sort_values(['type', 'name'])
# Out:
#            type                           name  \
# 0    classifier                    BernoulliNB
# 1    classifier         CalibratedClassifierCV
# 2    classifier                  CategoricalNB
# 3    classifier                ClassifierChain
# 4    classifier                   ComplementNB
# 5    classifier                DummyClassifier
# 6    classifier                     GaussianNB
# 7    classifier     LinearDiscriminantAnalysis
# 8    classifier          MultiOutputClassifier
# 9    classifier                  MultinomialNB
# 10   classifier             OneVsOneClassifier
# 11   classifier            OneVsRestClassifier
# 12   classifier           OutputCodeClassifier
# 13   classifier  QuadraticDiscriminantAnalysis
# 14    regressor                 DummyRegressor
# 15    regressor             IsotonicRegression
# 16    regressor                    KernelRidge
# 17    regressor           MultiOutputRegressor
# 18    regressor                 RegressorChain
# 19  transformer            AdditiveChi2Sampler
# 20  transformer                   FeatureUnion
# 21  transformer       GaussianRandomProjection
# 22  transformer              HashingVectorizer
# 23  transformer             IsotonicRegression
# 24  transformer     LinearDiscriminantAnalysis
# 25  transformer                       Nystroem
# 26  transformer                 PatchExtractor
# 27  transformer          PolynomialCountSketch
# 28  transformer                     RBFSampler
# 29  transformer              SkewedChi2Sampler
# 30  transformer         SparseRandomProjection
# 31  transformer               TfidfTransformer
#
#                                                 class
# 0                     sklearn.naive_bayes.BernoulliNB
# 1          sklearn.calibration.CalibratedClassifierCV
# 2                   sklearn.naive_bayes.CategoricalNB
# 3                 sklearn.multioutput.ClassifierChain
# 4                    sklearn.naive_bayes.ComplementNB
# 5                       sklearn.dummy.DummyClassifier
# 6                      sklearn.naive_bayes.GaussianNB
# 7   sklearn.discriminant_analysis.LinearDiscrimina...
# 8           sklearn.multioutput.MultiOutputClassifier
# 9                   sklearn.naive_bayes.MultinomialNB
# 10              sklearn.multiclass.OneVsOneClassifier
# 11             sklearn.multiclass.OneVsRestClassifier
# 12            sklearn.multiclass.OutputCodeClassifier
# 13  sklearn.discriminant_analysis.QuadraticDiscrim...
# 14                       sklearn.dummy.DummyRegressor
# 15                sklearn.isotonic.IsotonicRegression
# 16                   sklearn.kernel_ridge.KernelRidge
# 17           sklearn.multioutput.MultiOutputRegressor
# 18                 sklearn.multioutput.RegressorChain
# 19   sklearn.kernel_approximation.AdditiveChi2Sampler
# 20                      sklearn.pipeline.FeatureUnion
# 21  sklearn.random_projection.GaussianRandomProjec...
# 22  sklearn.feature_extraction.text.HashingVectorizer
# 23                sklearn.isotonic.IsotonicRegression
# 24  sklearn.discriminant_analysis.LinearDiscrimina...
# 25              sklearn.kernel_approximation.Nystroem
# 26    sklearn.feature_extraction.image.PatchExtractor
# 27  sklearn.kernel_approximation.PolynomialCountSk...
# 28            sklearn.kernel_approximation.RBFSampler
# 29     sklearn.kernel_approximation.SkewedChi2Sampler
# 30   sklearn.random_projection.SparseRandomProjection
# 31   sklearn.feature_extraction.text.TfidfTransformer

# %% [markdown]
# ## #03. sklearn 성능 측정
#
# ### [1] 반복 실행 후 평균 실행 시간 측정  (`%%timeit -r숫자 -n숫자`)
#
# `%%timeit` 명령이 상단에 명시된 블록은 기본적으로 100회 실행한다.
#
# 각 회차마다의 실행시간에 대한 평균을 마지막에 출력한다.
#
# `-r회차 -n회차` 옵션을 추가하면 반복 회차를 직접 조절할 수 있다.
#
# - `-r` : 몇 번 loop 돌 것인지를 설정
# - `-n` : 각 loop당 몇 번 실행할 것인지를 설정

# %%
# %%timeit -r2 -n3

filterType = ['classifier', 'regressor', 'cluster', 'transformer']
mylist = []

for f in filterType:
    allAlgorithms = all_estimators(type_filter=f)

    for name, package in allAlgorithms:
        cls = str(package)
        x = cls.find("'")
        y = cls.rfind("'")
        clsName = cls[x+1:y]

        if clsName.find("._") > -1:
            continue

        mylist.append({"type": f, "name": name, "class": clsName})

df = DataFrame(mylist)
df.head()
# Out:
# 623 ms ± 7.52 ms per loop (mean ± std. dev. of 2 runs, 3 loops each)

# %% [markdown]
# ### [2] 1회만 실행 후 시간 측정 (`%%time`)
#
# `%%timeit -r1 -n1`과 동일함

# %%
# %%time

filterType = ['classifier', 'regressor', 'cluster', 'transformer']
mylist = []

for f in filterType:
    allAlgorithms = all_estimators(type_filter=f)

    for name, package in allAlgorithms:
        cls = str(package)
        x = cls.find("'")
        y = cls.rfind("'")
        clsName = cls[x+1:y]

        if clsName.find("._") > -1:
            continue

        mylist.append({"type": f, "name": name, "class": clsName})

df = DataFrame(mylist)
df.head()
# Out:
# CPU times: total: 594 ms
# Wall time: 582 ms
#          type                    name  \
# 0  classifier             BernoulliNB
# 1  classifier  CalibratedClassifierCV
# 2  classifier           CategoricalNB
# 3  classifier         ClassifierChain
# 4  classifier            ComplementNB
#
#                                         class
# 0             sklearn.naive_bayes.BernoulliNB
# 1  sklearn.calibration.CalibratedClassifierCV
# 2           sklearn.naive_bayes.CategoricalNB
# 3         sklearn.multioutput.ClassifierChain
# 4            sklearn.naive_bayes.ComplementNB

# %% [markdown]
# ## #04. 사용되는 메모리 계산 (`%%memit`)
#
# `memory_profiler` 패키지 설치가 필요하다.
#
# 코드 블록 상단에 `%%memit` 명령을 명시하면 해당 블록이 실행되면서 소비되는 메모리 용량을 산정한다.
#
# ### [1] 외부 라이브러리 로딩

# %%
# %load_ext memory_profiler

# %% [markdown]
# ### [2] 시간 측정 + 메모리 사용량 계산

# %%
# %%time
# %%memit

filterType = ['classifier', 'regressor', 'cluster', 'transformer']
mylist = []

for f in filterType:
    allAlgorithms = all_estimators(type_filter=f)

    for name, package in allAlgorithms:
        cls = str(package)
        x = cls.find("'")
        y = cls.rfind("'")
        clsName = cls[x+1:y]

        if clsName.find("._") > -1:
            continue

        mylist.append({"type": f, "name": name, "class": clsName})

df = DataFrame(mylist)
df.head()
# Out:
# peak memory: 195.97 MiB, increment: 0.03 MiB
# CPU times: total: 1.05 s
# Wall time: 5.49 s
